# %% [markdown]
# # 🌙 Noor-e-Abjad Notebook
#
# > **Integration with Multimodal QuranLab**

# %%
import pandas as pd
df = pd.read_csv('../data/quran_abjad.csv')
print(f"Dataset integrated with Multimodal QuranLab: {len(df)} verses")
