# %% [markdown]
# <a href="https://www.kaggle.com/code/adnanmd76/noor-e-abjad-notebook?scriptVersionId=296523190" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>
