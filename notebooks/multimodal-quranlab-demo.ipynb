# %% [markdown]
# # 🌙 Multimodal QuranLab Demo
#
# > **Integrated demo using Kaggle datasets and Hugging Face models**

# %%
# !pip install -q transformers torch librosa soundfile pandas numpy

# %%
# Load multimodal model
from transformers import pipeline

audio_pipeline = pipeline("automatic-speech-recognition", model="ADANiD/multimodal-quranlab")
text_pipeline = pipeline("text-classification", model="ADANiD/Quranlab-AI")

# Load Kaggle dataset
import pandas as pd
abjad_df = pd.read_csv('/kaggle/input/nooreabjad-dataset/data/quran_abjad.csv')
print(f"Loaded {len(abjad_df)} verses from Kaggle dataset")
